# %% [markdown]
# <a href="https://colab.research.google.com/github/sarajay19/LLM/blob/main/Multi_Agent_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise: Building a Multi-Agent System
#
# In this exercise, we will create a simple multi-agent system where three agents collaborate to accomplish a common goal. The first agent will conduct a thorough interview, the second agent will Respond accurately to the interviewer’s questions, and the third agent will ensuring accurate insights are drawn from interview responses.
#
# ---
# ### Step 1: Install the Required Libraries

# %%
# !pip install crewai langchain langchain-community langchain_groq
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.10/dist-packages (0.60.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.16)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.17)
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.10/dist-packages (0.1.10)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python<5.0.0,>=4.7.1 in /usr/local/lib/python3.10/dist-packages (from crewai) (4.7.2)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from crewai) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in /usr/local/lib/python3.10/dist-packages (from crewai) (0.1.121)
# Requirement already satisfied: instructor==1.3.3 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from crewai) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm<2.0.0,>=1.44.22 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.46.1)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.45.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.27.0)
# Requirement already satisfied: poetry<2.0.0,>=1.8.3 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.8.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from crewai) (2.8.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from crewai) (1.0.1)
# Requirement already satisfied: regex<2025.0.0,>=2024.7.24 in /usr/local/lib/python3.10/dist-packages (from crewai) (2024.9.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (3.9.5)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (2.20.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (13.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (8.5.0)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from instructor==1.3.3->crewai) (0.12.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.40)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.121)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain_groq) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai) (1.9.4)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (43.0.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.9.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.7.1->crewai) (2.0.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.13.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.24 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.4.24)
# Requirement already satisfied: cohere<6.0,>=5.3 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (5.9.2)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (1.59.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.9)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.1.25)
# Requirement already satisfied: mem0ai<0.0.21,>=0.0.20 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.0.20)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (3.6.6)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.7)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from embedchain<0.2.0,>=0.1.114->crewai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (0.27.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.44.22->crewai) (8.0.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.44.22->crewai) (3.1.4)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from litellm<2.0.0,>=1.44.22->crewai) (0.19.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.13.3->crewai) (4.66.4)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai) (4.25.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai) (0.48b0)
# Requirement already satisfied: build<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.2.1)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (0.14.0)
# Requirement already satisfied: cleo<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.1.0)
# Requirement already satisfied: crashtest<0.5.0,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.4.1)
# Requirement already satisfied: dulwich<0.22.0,>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.21.7)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.20.0)
# Requirement already satisfied: installer<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.7.0)
# Requirement already satisfied: keyring<25.0.0,>=24.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (24.3.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (4.9.0)
# Requirement already satisfied: pkginfo<2.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.11.1)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (4.2.2)
# Requirement already satisfied: poetry-core==1.9.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.9.0)
# Requirement already satisfied: poetry-plugin-export<2.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.8.0)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.0.0)
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (1.5.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (2.0.1)
# Requirement already satisfied: tomlkit<1.0.0,>=0.11.4 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (0.13.2)
# Requirement already satisfied: trove-classifiers>=2022.5.19 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (2024.9.12)
# Requirement already satisfied: virtualenv<21.0.0,>=20.23.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.8.3->crewai) (20.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai) (1.3.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.114->crewai) (2.5)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (1.0.8)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0.0,>=1.8.3->crewai) (3.15.4)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.114.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.30.6)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.19.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.2.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from cleo<3.0.0,>=2.1.0->poetry<2.0.0,>=1.8.3->crewai) (3.9.7)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in /usr/local/lib/python3.10/dist-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.20)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.10/dist-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.9.7)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.10/dist-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (2.32.0.20240914)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<44.0.0,>=43.0.1->auth0-python<5.0.0,>=4.7.1->crewai) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai) (1.14.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.24.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.0.5)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.114->crewai) (5.4.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.44.22->crewai) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.44.22->crewai) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.44.22->crewai) (0.19.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.10/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (3.4.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (0.7.1)
# Requirement already satisfied: langchain-experimental>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.0.65)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2.0.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (0.9.0)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in /usr/local/lib/python3.10/dist-packages (from mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (1.11.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry<2.0.0,>=1.8.3->crewai) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (2.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers->litellm<2.0.0,>=1.44.22->crewai) (0.23.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv<21.0.0,>=20.23.0->poetry<2.0.0,>=1.8.3->crewai) (0.3.8)
# Requirement already satisfied: botocore<1.36.0,>=1.35.20 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.35.20)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai) (0.10.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python<5.0.0,>=4.7.1->crewai) (2.22)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.38.5)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.48.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.44.22->crewai) (2023.6.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai) (0.1.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.13.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (71.0.4)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (3.8.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai) (2024.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (1.62.3)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (2.10.1)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (13.0.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.8.3->crewai) (10.1.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (1.5.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (4.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai) (0.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.21,>=0.0.20->embedchain<0.2.0,>=0.1.114->crewai) (4.0.0)

# %% [markdown]
# ---
# ### Step 2: Import the Necessary Libraries

# %%
import os
from langchain_groq import ChatGroq
from crewai import Agentx
from crewai import Task
from crewai import Crew

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
llm = ChatGroq(
    model='groq/llama-3.1-70b-versatile',
    temperature=0.7,
    max_tokens= None,
    timeout=None,
    max_retries=2
)

# %% [markdown]
# ---
# ### Step 3: Create Agents

# %%
HR = Agent(
    llm=llm,
    role='Senior HR Employee',
    goal='Conduct a thorough interview with a candidate applying for the Data Analysis position, assessing their skills and fit for the role.',
    backstory='Your name is Mohammed. You are a Senior HR Employee with over 10 years of experience in recruitment and a background in business administration.',
    allow_delegation=False,
    verbose=1,
)

# %%
Candidate = Agent(
    llm=llm,
    role='Data Analysis Candidate',
    goal='Respond accurately to the interviewer’s questions, showcasing your skills and experiences to secure the position.',
    backstory='Your name is Sara. You are a recent graduate in Data Analysis with strong analytical and communication skills. You are eager to demonstrate your capabilities and secure your first professional role.',
    allow_delegation=False,
    verbose=1,
)

# %%
DA = Agent(
    llm=llm,
    role='Data Analysis Head',
    goal='Oversee the data analysis process, ensuring accurate insights are drawn from interview responses to improve recruitment strategies.',
    backstory='Your name is Nora. You are the Data Analysis Head with over 8 years of experience in data analytics and a strong background in statistics. You excel at transforming data into actionable insights.',
    allow_delegation=False,
    verbose=1,
)

# %% [markdown]
# ### Step 3: Create Tasks

# %%
task1 = Task(
    description="Create a detailed interview QA script for the Public Relations position, including questions that assess the candidate's background, skills, and cultural fit.",
    expected_output="A comprehensive interview QA script with clear, relevant questions tailored to evaluate the candidate's qualifications for the Data Analysis role.",
    output_file="interview_script.txt",
    agent=HR,
)

# %%
task2 = Task(
    description="Prepare and provide well-thought-out answers to the interview questions, demonstrating your qualifications and enthusiasm for the position.",
    expected_output="A structured response QA script that includes questions and answers and expresses gratitude to the interviewer.",
    output_file="interview_responses.txt",
    agent=Candidate,
    input_file='interview_script.txt',
)

# %%
task3 = Task(
    description="Analyze the interview responses from the candidate to identify strengths and areas for improvement, and generate a report summarizing the findings.",
    expected_output="A detailed analysis report highlighting key insights from the interview responses, including candidate strengths, potential concerns, and recommendations for the hiring team.",
    output_file="interview_analysis_report.txt",
    agent=DA,
    input_file='interview_responses.txt',
)

# %% [markdown]
# ---
# ### Step 4: Execute the Multi-Agent System

# %%
crew = Crew(agents=[HR, Candidate, DA], tasks=[task1, task2, task3], verbose=1)

print(crew.kickoff())
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Senior HR Employee
# ## Task: Create a detailed interview QA script for the Public Relations position, including questions that assess the candidate's background, skills, and cultural fit.
#
#
# # Agent: Senior HR Employee
# ## Final Answer:
# **Comprehensive Interview QA Script for the Public Relations Position**
#
# **Introduction:**
#
# Hello, welcome to the interview for the Public Relations position at our organization. My name is Mohammed, and I'm a Senior HR representative. I'll be your interviewer today. This assessment is designed to help us evaluate your qualifications, skills, and cultural fit for the role. Let's get started!
#
# **Section 1: Background and Experience (30 minutes)**
#
# 1. Can you tell us about your academic background and relevant courses that prepared you for a career in Public Relations?
# 2. Describe your previous work experience in Public Relations. What were your responsibilities, and what did you accomplish in those roles?
# 3. How did you become interested in Public Relations, and what motivates you to work in this field?
# 4. Can you share an example of a successful campaign or project you led or were part of? What was your role, and what did you learn from the experience?
# 5. Have you worked with different types of media, such as social media, print, or broadcast? Can you provide examples of your experience with each?
#
# **Section 2: Skills and Knowledge (45 minutes)**
#
# 1. What is your understanding of the role of a Public Relations professional in an organization? How do you stay up-to-date with industry trends and developments?
# 2. Can you describe your experience with crisis communications? How would you handle a sudden crisis or negative publicity?
# 3. How do you build and maintain relationships with key stakeholders, such as the media, customers, and investors?
# 4. Can you walk us through your process for developing a comprehensive communications plan? How do you measure its effectiveness?
# 5. What is your experience with event planning and management? Can you provide examples of successful events you've helped plan and execute?
#
# **Section 3: Case Study (30 minutes)**
#
# Imagine that our organization is facing a potential crisis due to a product recall. The media is calling, and we need to respond quickly to mitigate the damage.
#
# * How would you advise our leadership on the best course of action?
# * What measures would you take to communicate with key stakeholders, including customers, employees, and the media?
# * Can you describe a potential press release or statement you would draft in response to the crisis?
#
# **Section 4: Cultural Fit (20 minutes)**
#
# 1. Can you describe a time when you had to work with a team to resolve a complex issue or achieve a goal? What was your role, and what did you learn from the experience?
# 2. How do you handle feedback or constructive criticism? Can you provide an example?
# 3. Our organization values innovation, creativity, and transparency. Can you describe a project or initiative you led or were part of that embodied these values?
# 4. How do you prioritize your work when faced with multiple deadlines or competing demands? Can you give us an example?
# 5. Can you tell us about a time when you had to adapt to a new situation or change in your previous role? How did you handle the adjustment?
#
# **Closing and Questions:**
#
# * Is there anything you would like to add or discuss that we haven't covered in this interview?
# * Do you have any questions about the Public Relations position or our organization?
# * What are your long-term career goals, and how does this role align with your aspirations?
#
# Thank you for taking the time to meet with us today. We will be in touch soon to let you know the next steps in our process.
# # Agent: Data Analysis Candidate
# ## Task: Prepare and provide well-thought-out answers to the interview questions, demonstrating your qualifications and enthusiasm for the position.
#
#
# # Agent: Data Analysis Candidate
# ## Final Answer:
# **
#
# **Introduction:**
#
# Thank you, Mohammed, for the warm welcome. I'm excited to be here today and appreciate the opportunity to demonstrate my qualifications for the Public Relations position. I'm confident that my skills and experience make me a strong fit for this role.
#
# **Section 1: Background and Experience (30 minutes)**
#
# **Question 1: Can you tell us about your academic background and relevant courses that prepared you for a career in Public Relations?**
#
# I hold a Bachelor's degree in Data Analysis, but my strong aspiration towards Public Relations led me to take electives in Mass Communication, Public Speaking, and Writing for the Media. These courses helped me develop my research, writing, and communication skills, which I believe are essential for a career in Public Relations.
#
# **Question 2: Describe your previous work experience in Public Relations. What were your responsibilities, and what did you accomplish in those roles?**
#
# Although I'm a recent graduate, I gained relevant experience through internships and volunteer work. In my previous role as a Social Media Assistant, I was responsible for creating engaging content, managing social media campaigns, and analyzing metrics to measure campaign effectiveness. I successfully increased our social media following by 20% and improved engagement rates by 50% through targeted campaigns and content curation.
#
# **Question 3: How did you become interested in Public Relations, and what motivates you to work in this field?**
#
# I developed an interest in Public Relations through my coursework and involvement in extracurricular activities. I'm motivated by the opportunity to build and maintain relationships with key stakeholders, manage crises, and develop effective communication strategies that positively impact organizations and their audiences.
#
# **Question 4: Can you share an example of a successful campaign or project you led or were part of? What was your role, and what did you learn from the experience?**
#
# In my previous internship, I worked on a team to develop a social media campaign promoting a local non-profit organization's charity event. My role was to create engaging content, manage the campaign's social media presence, and analyze metrics to measure campaign effectiveness. We successfully increased event attendance by 30% and raised awareness about the organization's mission. I learned the importance of teamwork, strategic planning, and adapting to changing circumstances.
#
# **Question 5: Have you worked with different types of media, such as social media, print, or broadcast? Can you provide examples of your experience with each?**
#
# Yes, I have experience working with various types of media. In my previous role, I managed social media campaigns, created content for print publications, and assisted with broadcast media outreach. For example, I helped write and distribute press releases to local media outlets, which resulted in feature stories and interviews.
#
# **Section 2: Skills and Knowledge (45 minutes)**
#
# **Question 1: What is your understanding of the role of a Public Relations professional in an organization? How do you stay up-to-date with industry trends and developments?**
#
# I understand that a Public Relations professional plays a crucial role in maintaining an organization's reputation, building relationships with key stakeholders, and developing effective communication strategies. I stay up-to-date with industry trends and developments through attending webinars, reading industry publications, and participating in online forums and discussions.
#
# **Question 2: Can you describe your experience with crisis communications? How would you handle a sudden crisis or negative publicity?**
#
# Although I don't have direct experience with crisis communications, I've learned about crisis management principles and strategies through coursework and training. In the event of a crisis, I would follow established protocols, prioritize transparency and honesty, and work closely with key stakeholders to develop a response strategy that mitigates the negative impact.
#
# **Question 3: How do you build and maintain relationships with key stakeholders, such as the media, customers, and investors?**
#
# I believe building and maintaining relationships requires strong communication skills, empathy, and a willingness to listen and adapt. I would focus on developing personalized relationships with key stakeholders, staying responsive to their needs, and delivering value through effective communication and results-driven strategies.
#
# **Question 4: Can you walk us through your process for developing a comprehensive communications plan? How do you measure its effectiveness?**
#
# When developing a comprehensive communications plan, I would follow a structured approach that involves researching the organization's goals and objectives, identifying key stakeholders, and analyzing the competitive landscape. I would measure the plan's effectiveness through metrics such as engagement rates, media coverage, and business outcomes.
#
# **Question 5: What is your experience with event planning and management? Can you provide examples of successful events you've helped plan and execute?**
#
# I have experience assisting with event planning and management, including coordinating logistics, developing promotional materials, and managing day-of-event activities. For example, I helped plan a charity event that raised awareness and funds for a local non-profit organization.
#
# **Section 3: Case Study (30 minutes)**
#
# **Question 1: Imagine that our organization is facing a potential crisis due to a product recall. The media is calling, and we need to respond quickly to mitigate the damage.**
#
# I would advise our leadership to take immediate action to address the crisis, including:
#
# * Issuing a prompt statement acknowledging the issue and expressing concern for affected customers
# * Establishing a crisis management team to coordinate responses and address stakeholder concerns
# * Developing a comprehensive communications plan to address the recall and provide updates on corrective actions
#
# **Question 2: What measures would you take to communicate with key stakeholders, including customers, employees, and the media?**
#
# I would:
#
# * Develop clear, concise messaging and statements for key stakeholders
# * Utilize multiple channels to communicate, including social media, email, and traditional media outlets
# * Establish a dedicated inbox or phone line for customer inquiries and concerns
# * Provide regular updates on corrective actions and progress to stakeholders
#
# **Question 3: Can you describe a potential press release or statement you would draft in response to the crisis?**
#
# The press release or statement would:
#
# * Acknowledge the crisis and express concern for affected customers
# * Provide clear information about the recall and corrective actions
# * Outline steps the organization is taking to address the issue and prevent future occurrences
# * Express a commitment to transparency and open communication throughout the process
#
# **Section 4: Cultural Fit (20 minutes)**
#
# **Question 1: Can you describe a time when you had to work with a team to resolve a complex issue or achieve a goal? What was your role, and what did you learn from the experience?**
#
# In a group project, we worked together to develop a social media campaign promoting a local business. I contributed by creating engaging content, managing the campaign's social media presence, and analyzing metrics to measure campaign effectiveness. I learned the importance of teamwork, clear communication, and adapting to changing circumstances.
#
# **Question 2: How do you handle feedback or constructive criticism? Can you provide an example?**
#
# I welcome feedback and constructive criticism as opportunities for growth and improvement. For example, in a previous role, I received feedback on my writing style, which I used to refine my skills and develop more engaging content.
#
# **Question 3: Our organization values innovation, creativity, and transparency. Can you describe a project or initiative you led or were part of that embodied these values?**
#
# In a previous role, I developed a social media campaign promoting a local non-profit organization's charity event. I used innovative tactics, such as gamification and user-generated content, to engage the audience and increase event attendance. I prioritized transparency by providing regular updates and behind-the-scenes insights into the campaign's development and execution.
#
# **Question 4: How do you prioritize your work when faced with multiple deadlines or competing demands? Can you give us an example?**
#
# I prioritize tasks based on urgency and importance, focusing on the most critical tasks first and delegating or adjusting timelines as needed. For example, in a previous role, I managed multiple social media campaigns simultaneously, prioritizing tasks by importance and deadlines to ensure successful execution.
#
# **Question 5: Can you tell us about a time when you had to adapt to a new situation or change in your previous role? How did you handle the adjustment?**
#
# In a previous internship, I was tasked with adapting to a new social media management tool. I quickly learned the new tool by completing tutorials, attending training sessions, and seeking guidance from colleagues.
#
# **Closing and Questions:**
#
# **Question 1: Is there anything you would like to add or discuss that we haven't covered in this interview?**
#
# I appreciate the opportunity to emphasize my passion for Public Relations and my eagerness to learn and grow with this organization.
#
# **Question 2: Do you have any questions about the Public Relations position or our organization?**
#
# I would like to know more about the day-to-day responsibilities of the position, the team I would be working with, and opportunities for professional development and growth within the organization.
#
# **Question 3: What are your long-term career goals, and how does this role align with your aspirations?**
#
# In the long term, I aim to become a senior Public Relations professional with a specialization in crisis communications and reputation management. This role aligns with my aspirations by providing opportunities for growth, professional development, and contributing to an organization that values innovation, creativity, and transparency.
#
# Thank you, Mohammed, for the opportunity to demonstrate my qualifications for the Public Relations position. I'm confident that my skills, experience, and passion make me a strong fit for this role, and I look forward to the opportunity to contribute to this organization.
# # Agent: Data Analysis Head
# ## Task: Analyze the interview responses from the candidate to identify strengths and areas for improvement, and generate a report summarizing the findings.
#
#
# # Agent: Data Analysis Head
# ## Final Answer:
# **Candidate Analysis Report**
#
# **Introduction:**
#
# This report provides an in-depth analysis of the candidate's interview responses, highlighting strengths, areas for improvement, and recommendations for the hiring team. The candidate demonstrated a strong passion for Public Relations and a desire to grow with the organization.
#
# **Candidate Strengths:**
#
# 1. **Strong academic foundation**: The candidate holds a Bachelor's degree in Data Analysis and took electives in Mass Communication, Public Speaking, and Writing for the Media, which demonstrates a strong academic foundation in Public Relations.
# 2. **Relevant experience**: The candidate has gained relevant experience through internships and volunteer work, including social media management, content creation, and event planning.
# 3. **Excellent communication skills**: The candidate displayed excellent communication skills throughout the interview, answering questions clearly and concisely.
# 4. **Strategic thinking**: The candidate demonstrated strategic thinking in response to the crisis management scenario, outlining a comprehensive communications plan to address the issue.
# 5. **Passion for Public Relations**: The candidate expressed a genuine passion for Public Relations and a desire to learn and grow with the organization.
#
# **Areas for Improvement:**
#
# 1. **Lack of direct experience in crisis communications**: Although the candidate has knowledge of crisis management principles and strategies, they lack direct experience in this area.
# 2. **Limited experience with traditional media**: The candidate's experience with traditional media outlets is limited, which may impact their ability to handle media inquiries and interviews.
# 3. **Need for further development in event planning**: While the candidate has experience assisting with event planning, they may require further development to take on more significant responsibilities in this area.
#
# **Recommendations:**
#
# 1. **Provide training and development opportunities in crisis communications**: To address the candidate's lack of direct experience in crisis communications, provide training and development opportunities to enhance their skills in this area.
# 2. **Offer guidance on traditional media relations**: Provide guidance and support to help the candidate develop their skills in traditional media relations, including handling media inquiries and interviews.
# 3. **Assign a mentor**: Assign a mentor to provide guidance and support throughout the onboarding process and beyond.
# 4. **Monitor progress and provide feedback**: Regularly monitor the candidate's progress and provide constructive feedback to help them grow and develop in the role.
#
# **Conclusion:**
#
# The candidate demonstrated a strong passion for Public Relations and a desire to learn and grow with the organization. While they possess some areas for improvement, these can be addressed through training and development opportunities. With guidance and support, the candidate has the potential to become a valuable member of the team.
#
# **Rating:**
#
# * **Overall rating:** 8.5/10
# * **Recommendation:** Hire the candidate, provided that the areas for improvement are addressed through training and development opportunities.
#
# **Recommendations for the Hiring Team:**
#
# * **Training and development plan**: Develop a comprehensive training and development plan to address the candidate's areas for improvement.
# * **Regular check-ins**: Schedule regular check-ins with the candidate to monitor their progress and provide feedback.
# * **Mentorship**: Assign a mentor to provide guidance and support throughout the onboarding process and beyond.
#
# By following these recommendations, the hiring team can ensure that the candidate receives the support and development opportunities needed to succeed in the role and contribute to the organization's success.
# **Candidate Analysis Report**
#
# **Introduction:**
#
# This report provides an in-depth analysis of the candidate's interview responses, highlighting strengths, areas for improvement, and recommendations for the hiring team. The candidate demonstrated a strong passion for Public Relations and a desire to grow with the organization.
#
# **Candidate Strengths:**
#
# 1. **Strong academic foundation**: The candidate holds a Bachelor's degree in Data Analysis and took electives in Mass Communication, Public Speaking, and Writing for the Media, which demonstrates a strong academic foundation in Public Relations.
# 2. **Relevant experience**: The candidate has gained relevant experience through internships and volunteer work, including social media management, content creation, and event planning.
# 3. **Excellent communication skills**: The candidate displayed excellent communication skills throughout the interview, answering questions clearly and concisely.
# 4. **Strategic thinking**: The candidate demonstrated strategic thinking in response to the crisis management scenario, outlining a comprehensive communications plan to address the issue.
# 5. **Passion for Public Relations**: The candidate expressed a genuine passion for Public Relations and a desire to learn and grow with the organization.
#
# **Areas for Improvement:**
#
# 1. **Lack of direct experience in crisis communications**: Although the candidate has knowledge of crisis management principles and strategies, they lack direct experience in this area.
# 2. **Limited experience with traditional media**: The candidate's experience with traditional media outlets is limited, which may impact their ability to handle media inquiries and interviews.
# 3. **Need for further development in event planning**: While the candidate has experience assisting with event planning, they may require further development to take on more significant responsibilities in this area.
#
# **Recommendations:**
#
# 1. **Provide training and development opportunities in crisis communications**: To address the candidate's lack of direct experience in crisis communications, provide training and development opportunities to enhance their skills in this area.
# 2. **Offer guidance on traditional media relations**: Provide guidance and support to help the candidate develop their skills in traditional media relations, including handling media inquiries and interviews.
# 3. **Assign a mentor**: Assign a mentor to provide guidance and support throughout the onboarding process and beyond.
# 4. **Monitor progress and provide feedback**: Regularly monitor the candidate's progress and provide constructive feedback to help them grow and develop in the role.
#
# **Conclusion:**
#
# The candidate demonstrated a strong passion for Public Relations and a desire to learn and grow with the organization. While they possess some areas for improvement, these can be addressed through training and development opportunities. With guidance and support, the candidate has the potential to become a valuable member of the team.
#
# **Rating:**
#
# * **Overall rating:** 8.5/10
# * **Recommendation:** Hire the candidate, provided that the areas for improvement are addressed through training and development opportunities.
#
# **Recommendations for the Hiring Team:**
#
# * **Training and development plan**: Develop a comprehensive training and development plan to address the candidate's areas for improvement.
# * **Regular check-ins**: Schedule regular check-ins with the candidate to monitor their progress and provide feedback.
# * **Mentorship**: Assign a mentor to provide guidance and support throughout the onboarding process and beyond.
#
# By following these recommendations, the hiring team can ensure that the candidate receives the support and development opportunities needed to succeed in the role and contribute to the organization's success.
